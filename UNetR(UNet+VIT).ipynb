# %% [markdown]
# <a href="https://colab.research.google.com/github/Nobel712/Image-Segmentation/blob/main/UNetR(UNet%2BVIT).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow.keras.layers as L
from tensorflow.keras.models import Model

# %%
def mlp(x, cf):
    x = L.Dense(cf["mlp_dim"], activation="gelu")(x)
    x = L.Dropout(cf["dropout_rate"])(x)
    x = L.Dense(cf["hidden_dim"])(x)
    x = L.Dropout(cf["dropout_rate"])(x)
    return x

def transformer_encoder(x, cf):
    skip_1 = x
    x = L.LayerNormalization()(x)
    x = L.MultiHeadAttention(
        num_heads=cf["num_heads"], key_dim=cf["hidden_dim"]
    )(x, x)
    x = L.Add()([x, skip_1])

    skip_2 = x
    x = L.LayerNormalization()(x)
    x = mlp(x, cf)
    x = L.Add()([x, skip_2])

    return x

def conv_block(x, num_filters, kernel_size=3):
    x = L.Conv2D(num_filters, kernel_size=kernel_size, padding="same")(x)
    x = L.BatchNormalization()(x)
    x = L.ReLU()(x)
    return x

def deconv_block(x, num_filters):
    x = L.Conv2DTranspose(num_filters, kernel_size=2, padding="same", strides=2)(x)
    return x

# %%
def build_unetr_2d(cf):
    """ Inputs """
    input_shape = (cf["num_patches"], cf["patch_size"]*cf["patch_size"]*cf["num_channels"])
    inputs = L.Input(input_shape) ## (None, 256, 3072)

    """ Patch + Position Embeddings """
    patch_embed = L.Dense(cf["hidden_dim"])(inputs) ## (None, 256, 768)

    positions = tf.range(start=0, limit=cf["num_patches"], delta=1) ## (256,)
    pos_embed = L.Embedding(input_dim=cf["num_patches"], output_dim=cf["hidden_dim"])(positions) ## (256, 768)
    x = patch_embed + pos_embed ## (None, 256, 768)

    """ Transformer Encoder """
    skip_connection_index = [3, 6, 9, 12]
    skip_connections = []

    for i in range(1, cf["num_layers"]+1, 1):
        x = transformer_encoder(x, cf)

        if i in skip_connection_index:
            skip_connections.append(x)

    """ CNN Decoder """
    z3, z6, z9, z12 = skip_connections

    ## Reshaping
    z0 = L.Reshape((cf["image_size"], cf["image_size"], cf["num_channels"]))(inputs)
    z3 = L.Reshape((cf["patch_size"], cf["patch_size"], cf["hidden_dim"]))(z3)
    z6 = L.Reshape((cf["patch_size"], cf["patch_size"], cf["hidden_dim"]))(z6)
    z9 = L.Reshape((cf["patch_size"], cf["patch_size"], cf["hidden_dim"]))(z9)
    z12 = L.Reshape((cf["patch_size"], cf["patch_size"], cf["hidden_dim"]))(z12)

    ## Decoder 1
    x = deconv_block(z12, 512)

    s = deconv_block(z9, 512)
    s = conv_block(s, 512)
    x = L.Concatenate()([x, s])

    x = conv_block(x, 512)
    x = conv_block(x, 512)

    ## Decoder 2
    x = deconv_block(x, 256)

    s = deconv_block(z6, 256)
    s = conv_block(s, 256)
    s = deconv_block(s, 256)
    s = conv_block(s, 256)

    x = L.Concatenate()([x, s])
    x = conv_block(x, 256)
    x = conv_block(x, 256)

    ## Decoder 3
    x = deconv_block(x, 128)

    s = deconv_block(z3, 128)
    s = conv_block(s, 128)
    s = deconv_block(s, 128)
    s = conv_block(s, 128)
    s = deconv_block(s, 128)
    s = conv_block(s, 128)

    x = L.Concatenate()([x, s])
    x = conv_block(x, 128)
    x = conv_block(x, 128)

    ## Decoder 4
    x = deconv_block(x, 64)

    s = conv_block(z0, 64)
    s = conv_block(s, 64)

    x = L.Concatenate()([x, s])
    x = conv_block(x, 64)
    x = conv_block(x, 64)

    """ Output """
    outputs = L.Conv2D(1, kernel_size=1, padding="same", activation="sigmoid")(x)

    return Model(inputs, outputs, name="UNETR_2D")

# %%
if __name__ == "__main__":
    config = {}
    config["image_size"] = 256
    config["num_layers"] = 12
    config["hidden_dim"] = 768
    config["mlp_dim"] = 3072
    config["num_heads"] = 12
    config["dropout_rate"] = 0.1
    config["num_patches"] = 256
    config["patch_size"] = 16
    config["num_channels"] = 3

    model = build_unetr_2d(config)
    model.summary()
# Out:
# Model: "UNETR_2D"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 256, 768)]   0           []
#
#  dense_125 (Dense)              (None, 256, 768)     590592      ['input_6[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 256, 768)    0           ['dense_125[0][0]']
#  mbda)
#
#  layer_normalization_120 (Layer  (None, 256, 768)    1536        ['tf.__operators__.add_5[0][0]']
#  Normalization)
#
#  multi_head_attention_60 (Multi  (None, 256, 768)    28339968    ['layer_normalization_120[0][0]',
#  HeadAttention)                                                   'layer_normalization_120[0][0]']
#
#  add_120 (Add)                  (None, 256, 768)     0           ['multi_head_attention_60[0][0]',
#                                                                   'tf.__operators__.add_5[0][0]']
#
#  layer_normalization_121 (Layer  (None, 256, 768)    1536        ['add_120[0][0]']
#  Normalization)
#
#  dense_126 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_121[0][0]']
#
#  dropout_120 (Dropout)          (None, 256, 3072)    0           ['dense_126[0][0]']
#
#  dense_127 (Dense)              (None, 256, 768)     2360064     ['dropout_120[0][0]']
#
#  dropout_121 (Dropout)          (None, 256, 768)     0           ['dense_127[0][0]']
#
#  add_121 (Add)                  (None, 256, 768)     0           ['dropout_121[0][0]',
#                                                                   'add_120[0][0]']
#
#  layer_normalization_122 (Layer  (None, 256, 768)    1536        ['add_121[0][0]']
#  Normalization)
#
#  multi_head_attention_61 (Multi  (None, 256, 768)    28339968    ['layer_normalization_122[0][0]',
#  HeadAttention)                                                   'layer_normalization_122[0][0]']
#
#  add_122 (Add)                  (None, 256, 768)     0           ['multi_head_attention_61[0][0]',
#                                                                   'add_121[0][0]']
#
#  layer_normalization_123 (Layer  (None, 256, 768)    1536        ['add_122[0][0]']
#  Normalization)
#
#  dense_128 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_123[0][0]']
#
#  dropout_122 (Dropout)          (None, 256, 3072)    0           ['dense_128[0][0]']
#
#  dense_129 (Dense)              (None, 256, 768)     2360064     ['dropout_122[0][0]']
#
#  dropout_123 (Dropout)          (None, 256, 768)     0           ['dense_129[0][0]']
#
#  add_123 (Add)                  (None, 256, 768)     0           ['dropout_123[0][0]',
#                                                                   'add_122[0][0]']
#
#  layer_normalization_124 (Layer  (None, 256, 768)    1536        ['add_123[0][0]']
#  Normalization)
#
#  multi_head_attention_62 (Multi  (None, 256, 768)    28339968    ['layer_normalization_124[0][0]',
#  HeadAttention)                                                   'layer_normalization_124[0][0]']
#
#  add_124 (Add)                  (None, 256, 768)     0           ['multi_head_attention_62[0][0]',
#                                                                   'add_123[0][0]']
#
#  layer_normalization_125 (Layer  (None, 256, 768)    1536        ['add_124[0][0]']
#  Normalization)
#
#  dense_130 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_125[0][0]']
#
#  dropout_124 (Dropout)          (None, 256, 3072)    0           ['dense_130[0][0]']
#
#  dense_131 (Dense)              (None, 256, 768)     2360064     ['dropout_124[0][0]']
#
#  dropout_125 (Dropout)          (None, 256, 768)     0           ['dense_131[0][0]']
#
#  add_125 (Add)                  (None, 256, 768)     0           ['dropout_125[0][0]',
#                                                                   'add_124[0][0]']
#
#  layer_normalization_126 (Layer  (None, 256, 768)    1536        ['add_125[0][0]']
#  Normalization)
#
#  multi_head_attention_63 (Multi  (None, 256, 768)    28339968    ['layer_normalization_126[0][0]',
#  HeadAttention)                                                   'layer_normalization_126[0][0]']
#
#  add_126 (Add)                  (None, 256, 768)     0           ['multi_head_attention_63[0][0]',
#                                                                   'add_125[0][0]']
#
#  layer_normalization_127 (Layer  (None, 256, 768)    1536        ['add_126[0][0]']
#  Normalization)
#
#  dense_132 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_127[0][0]']
#
#  dropout_126 (Dropout)          (None, 256, 3072)    0           ['dense_132[0][0]']
#
#  dense_133 (Dense)              (None, 256, 768)     2360064     ['dropout_126[0][0]']
#
#  dropout_127 (Dropout)          (None, 256, 768)     0           ['dense_133[0][0]']
#
#  add_127 (Add)                  (None, 256, 768)     0           ['dropout_127[0][0]',
#                                                                   'add_126[0][0]']
#
#  layer_normalization_128 (Layer  (None, 256, 768)    1536        ['add_127[0][0]']
#  Normalization)
#
#  multi_head_attention_64 (Multi  (None, 256, 768)    28339968    ['layer_normalization_128[0][0]',
#  HeadAttention)                                                   'layer_normalization_128[0][0]']
#
#  add_128 (Add)                  (None, 256, 768)     0           ['multi_head_attention_64[0][0]',
#                                                                   'add_127[0][0]']
#
#  layer_normalization_129 (Layer  (None, 256, 768)    1536        ['add_128[0][0]']
#  Normalization)
#
#  dense_134 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_129[0][0]']
#
#  dropout_128 (Dropout)          (None, 256, 3072)    0           ['dense_134[0][0]']
#
#  dense_135 (Dense)              (None, 256, 768)     2360064     ['dropout_128[0][0]']
#
#  dropout_129 (Dropout)          (None, 256, 768)     0           ['dense_135[0][0]']
#
#  add_129 (Add)                  (None, 256, 768)     0           ['dropout_129[0][0]',
#                                                                   'add_128[0][0]']
#
#  layer_normalization_130 (Layer  (None, 256, 768)    1536        ['add_129[0][0]']
#  Normalization)
#
#  multi_head_attention_65 (Multi  (None, 256, 768)    28339968    ['layer_normalization_130[0][0]',
#  HeadAttention)                                                   'layer_normalization_130[0][0]']
#
#  add_130 (Add)                  (None, 256, 768)     0           ['multi_head_attention_65[0][0]',
#                                                                   'add_129[0][0]']
#
#  layer_normalization_131 (Layer  (None, 256, 768)    1536        ['add_130[0][0]']
#  Normalization)
#
#  dense_136 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_131[0][0]']
#
#  dropout_130 (Dropout)          (None, 256, 3072)    0           ['dense_136[0][0]']
#
#  dense_137 (Dense)              (None, 256, 768)     2360064     ['dropout_130[0][0]']
#
#  dropout_131 (Dropout)          (None, 256, 768)     0           ['dense_137[0][0]']
#
#  add_131 (Add)                  (None, 256, 768)     0           ['dropout_131[0][0]',
#                                                                   'add_130[0][0]']
#
#  layer_normalization_132 (Layer  (None, 256, 768)    1536        ['add_131[0][0]']
#  Normalization)
#
#  multi_head_attention_66 (Multi  (None, 256, 768)    28339968    ['layer_normalization_132[0][0]',
#  HeadAttention)                                                   'layer_normalization_132[0][0]']
#
#  add_132 (Add)                  (None, 256, 768)     0           ['multi_head_attention_66[0][0]',
#                                                                   'add_131[0][0]']
#
#  layer_normalization_133 (Layer  (None, 256, 768)    1536        ['add_132[0][0]']
#  Normalization)
#
#  dense_138 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_133[0][0]']
#
#  dropout_132 (Dropout)          (None, 256, 3072)    0           ['dense_138[0][0]']
#
#  dense_139 (Dense)              (None, 256, 768)     2360064     ['dropout_132[0][0]']
#
#  dropout_133 (Dropout)          (None, 256, 768)     0           ['dense_139[0][0]']
#
#  add_133 (Add)                  (None, 256, 768)     0           ['dropout_133[0][0]',
#                                                                   'add_132[0][0]']
#
#  layer_normalization_134 (Layer  (None, 256, 768)    1536        ['add_133[0][0]']
#  Normalization)
#
#  multi_head_attention_67 (Multi  (None, 256, 768)    28339968    ['layer_normalization_134[0][0]',
#  HeadAttention)                                                   'layer_normalization_134[0][0]']
#
#  add_134 (Add)                  (None, 256, 768)     0           ['multi_head_attention_67[0][0]',
#                                                                   'add_133[0][0]']
#
#  layer_normalization_135 (Layer  (None, 256, 768)    1536        ['add_134[0][0]']
#  Normalization)
#
#  dense_140 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_135[0][0]']
#
#  dropout_134 (Dropout)          (None, 256, 3072)    0           ['dense_140[0][0]']
#
#  dense_141 (Dense)              (None, 256, 768)     2360064     ['dropout_134[0][0]']
#
#  dropout_135 (Dropout)          (None, 256, 768)     0           ['dense_141[0][0]']
#
#  add_135 (Add)                  (None, 256, 768)     0           ['dropout_135[0][0]',
#                                                                   'add_134[0][0]']
#
#  layer_normalization_136 (Layer  (None, 256, 768)    1536        ['add_135[0][0]']
#  Normalization)
#
#  multi_head_attention_68 (Multi  (None, 256, 768)    28339968    ['layer_normalization_136[0][0]',
#  HeadAttention)                                                   'layer_normalization_136[0][0]']
#
#  add_136 (Add)                  (None, 256, 768)     0           ['multi_head_attention_68[0][0]',
#                                                                   'add_135[0][0]']
#
#  layer_normalization_137 (Layer  (None, 256, 768)    1536        ['add_136[0][0]']
#  Normalization)
#
#  dense_142 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_137[0][0]']
#
#  dropout_136 (Dropout)          (None, 256, 3072)    0           ['dense_142[0][0]']
#
#  dense_143 (Dense)              (None, 256, 768)     2360064     ['dropout_136[0][0]']
#
#  dropout_137 (Dropout)          (None, 256, 768)     0           ['dense_143[0][0]']
#
#  add_137 (Add)                  (None, 256, 768)     0           ['dropout_137[0][0]',
#                                                                   'add_136[0][0]']
#
#  layer_normalization_138 (Layer  (None, 256, 768)    1536        ['add_137[0][0]']
#  Normalization)
#
#  multi_head_attention_69 (Multi  (None, 256, 768)    28339968    ['layer_normalization_138[0][0]',
#  HeadAttention)                                                   'layer_normalization_138[0][0]']
#
#  add_138 (Add)                  (None, 256, 768)     0           ['multi_head_attention_69[0][0]',
#                                                                   'add_137[0][0]']
#
#  layer_normalization_139 (Layer  (None, 256, 768)    1536        ['add_138[0][0]']
#  Normalization)
#
#  dense_144 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_139[0][0]']
#
#  dropout_138 (Dropout)          (None, 256, 3072)    0           ['dense_144[0][0]']
#
#  dense_145 (Dense)              (None, 256, 768)     2360064     ['dropout_138[0][0]']
#
#  dropout_139 (Dropout)          (None, 256, 768)     0           ['dense_145[0][0]']
#
#  add_139 (Add)                  (None, 256, 768)     0           ['dropout_139[0][0]',
#                                                                   'add_138[0][0]']
#
#  layer_normalization_140 (Layer  (None, 256, 768)    1536        ['add_139[0][0]']
#  Normalization)
#
#  multi_head_attention_70 (Multi  (None, 256, 768)    28339968    ['layer_normalization_140[0][0]',
#  HeadAttention)                                                   'layer_normalization_140[0][0]']
#
#  add_140 (Add)                  (None, 256, 768)     0           ['multi_head_attention_70[0][0]',
#                                                                   'add_139[0][0]']
#
#  layer_normalization_141 (Layer  (None, 256, 768)    1536        ['add_140[0][0]']
#  Normalization)
#
#  dense_146 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_141[0][0]']
#
#  dropout_140 (Dropout)          (None, 256, 3072)    0           ['dense_146[0][0]']
#
#  dense_147 (Dense)              (None, 256, 768)     2360064     ['dropout_140[0][0]']
#
#  dropout_141 (Dropout)          (None, 256, 768)     0           ['dense_147[0][0]']
#
#  add_141 (Add)                  (None, 256, 768)     0           ['dropout_141[0][0]',
#                                                                   'add_140[0][0]']
#
#  layer_normalization_142 (Layer  (None, 256, 768)    1536        ['add_141[0][0]']
#  Normalization)
#
#  multi_head_attention_71 (Multi  (None, 256, 768)    28339968    ['layer_normalization_142[0][0]',
#  HeadAttention)                                                   'layer_normalization_142[0][0]']
#
#  add_142 (Add)                  (None, 256, 768)     0           ['multi_head_attention_71[0][0]',
#                                                                   'add_141[0][0]']
#
#  layer_normalization_143 (Layer  (None, 256, 768)    1536        ['add_142[0][0]']
#  Normalization)
#
#  dense_148 (Dense)              (None, 256, 3072)    2362368     ['layer_normalization_143[0][0]']
#
#  dropout_142 (Dropout)          (None, 256, 3072)    0           ['dense_148[0][0]']
#
#  dense_149 (Dense)              (None, 256, 768)     2360064     ['dropout_142[0][0]']
#
#  reshape_26 (Reshape)           (None, 16, 16, 768)  0           ['add_137[0][0]']
#
#  dropout_143 (Dropout)          (None, 256, 768)     0           ['dense_149[0][0]']
#
#  conv2d_transpose_41 (Conv2DTra  (None, 32, 32, 512)  1573376    ['reshape_26[0][0]']
#  nspose)
#
#  add_143 (Add)                  (None, 256, 768)     0           ['dropout_143[0][0]',
#                                                                   'add_142[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_transpose_41[0][0]']
#
#  reshape_27 (Reshape)           (None, 16, 16, 768)  0           ['add_143[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_54[0][0]']
#  ormalization)
#
#  conv2d_transpose_40 (Conv2DTra  (None, 32, 32, 512)  1573376    ['reshape_27[0][0]']
#  nspose)
#
#  re_lu_54 (ReLU)                (None, 32, 32, 512)  0           ['batch_normalization_54[0][0]']
#
#  reshape_25 (Reshape)           (None, 16, 16, 768)  0           ['add_131[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 32, 32, 1024  0           ['conv2d_transpose_40[0][0]',
#                                 )                                 're_lu_54[0][0]']
#
#  conv2d_transpose_43 (Conv2DTra  (None, 32, 32, 256)  786688     ['reshape_25[0][0]']
#  nspose)
#
#  conv2d_55 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate_15[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 32, 32, 256)  590080      ['conv2d_transpose_43[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_57[0][0]']
#  ormalization)
#
#  re_lu_55 (ReLU)                (None, 32, 32, 512)  0           ['batch_normalization_55[0][0]']
#
#  re_lu_57 (ReLU)                (None, 32, 32, 256)  0           ['batch_normalization_57[0][0]']
#
#  reshape_24 (Reshape)           (None, 16, 16, 768)  0           ['add_125[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 32, 32, 512)  2359808     ['re_lu_55[0][0]']
#
#  conv2d_transpose_44 (Conv2DTra  (None, 64, 64, 256)  262400     ['re_lu_57[0][0]']
#  nspose)
#
#  conv2d_transpose_46 (Conv2DTra  (None, 32, 32, 128)  393344     ['reshape_24[0][0]']
#  nspose)
#
#  batch_normalization_56 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_56[0][0]']
#  ormalization)
#
#  conv2d_58 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_transpose_44[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_transpose_46[0][0]']
#
#  re_lu_56 (ReLU)                (None, 32, 32, 512)  0           ['batch_normalization_56[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_61 (BatchN  (None, 32, 32, 128)  512        ['conv2d_61[0][0]']
#  ormalization)
#
#  conv2d_transpose_42 (Conv2DTra  (None, 64, 64, 256)  524544     ['re_lu_56[0][0]']
#  nspose)
#
#  re_lu_58 (ReLU)                (None, 64, 64, 256)  0           ['batch_normalization_58[0][0]']
#
#  re_lu_61 (ReLU)                (None, 32, 32, 128)  0           ['batch_normalization_61[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_transpose_42[0][0]',
#                                                                   're_lu_58[0][0]']
#
#  conv2d_transpose_47 (Conv2DTra  (None, 64, 64, 128)  65664      ['re_lu_61[0][0]']
#  nspose)
#
#  conv2d_59 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_16[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 64, 64, 128)  147584      ['conv2d_transpose_47[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_59[0][0]']
#  ormalization)
#
#  batch_normalization_62 (BatchN  (None, 64, 64, 128)  512        ['conv2d_62[0][0]']
#  ormalization)
#
#  re_lu_59 (ReLU)                (None, 64, 64, 256)  0           ['batch_normalization_59[0][0]']
#
#  re_lu_62 (ReLU)                (None, 64, 64, 128)  0           ['batch_normalization_62[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 64, 64, 256)  590080      ['re_lu_59[0][0]']
#
#  conv2d_transpose_48 (Conv2DTra  (None, 128, 128, 12  65664      ['re_lu_62[0][0]']
#  nspose)                        8)
#
#  batch_normalization_60 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_60[0][0]']
#  ormalization)
#
#  conv2d_63 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_transpose_48[0][0]']
#                                 8)
#
#  re_lu_60 (ReLU)                (None, 64, 64, 256)  0           ['batch_normalization_60[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 128, 128, 12  512        ['conv2d_63[0][0]']
#  ormalization)                  8)
#
#  conv2d_transpose_45 (Conv2DTra  (None, 128, 128, 12  131200     ['re_lu_60[0][0]']
#  nspose)                        8)
#
#  re_lu_63 (ReLU)                (None, 128, 128, 12  0           ['batch_normalization_63[0][0]']
#                                 8)
#
#  concatenate_17 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_transpose_45[0][0]',
#                                 6)                                're_lu_63[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_17[0][0]']
#                                 8)
#
#  reshape_23 (Reshape)           (None, 256, 256, 3)  0           ['input_6[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 128, 128, 12  512        ['conv2d_64[0][0]']
#  ormalization)                  8)
#
#  conv2d_66 (Conv2D)             (None, 256, 256, 64  1792        ['reshape_23[0][0]']
#                                 )
#
#  re_lu_64 (ReLU)                (None, 128, 128, 12  0           ['batch_normalization_64[0][0]']
#                                 8)
#
#  batch_normalization_66 (BatchN  (None, 256, 256, 64  256        ['conv2d_66[0][0]']
#  ormalization)                  )
#
#  conv2d_65 (Conv2D)             (None, 128, 128, 12  147584      ['re_lu_64[0][0]']
#                                 8)
#
#  re_lu_66 (ReLU)                (None, 256, 256, 64  0           ['batch_normalization_66[0][0]']
#                                 )
#
#  batch_normalization_65 (BatchN  (None, 128, 128, 12  512        ['conv2d_65[0][0]']
#  ormalization)                  8)
#
#  conv2d_67 (Conv2D)             (None, 256, 256, 64  36928       ['re_lu_66[0][0]']
#                                 )
#
#  re_lu_65 (ReLU)                (None, 128, 128, 12  0           ['batch_normalization_65[0][0]']
#                                 8)
#
#  batch_normalization_67 (BatchN  (None, 256, 256, 64  256        ['conv2d_67[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_49 (Conv2DTra  (None, 256, 256, 64  32832      ['re_lu_65[0][0]']
#  nspose)                        )
#
#  re_lu_67 (ReLU)                (None, 256, 256, 64  0           ['batch_normalization_67[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 256, 256, 12  0           ['conv2d_transpose_49[0][0]',
#                                 8)                                're_lu_67[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_18[0][0]']
#                                 )
#
#  batch_normalization_68 (BatchN  (None, 256, 256, 64  256        ['conv2d_68[0][0]']
#  ormalization)                  )
#
#  re_lu_68 (ReLU)                (None, 256, 256, 64  0           ['batch_normalization_68[0][0]']
#                                 )
#
#  conv2d_69 (Conv2D)             (None, 256, 256, 64  36928       ['re_lu_68[0][0]']
#                                 )
#
#  batch_normalization_69 (BatchN  (None, 256, 256, 64  256        ['conv2d_69[0][0]']
#  ormalization)                  )
#
#  re_lu_69 (ReLU)                (None, 256, 256, 64  0           ['batch_normalization_69[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 256, 256, 1)  65          ['re_lu_69[0][0]']
#
# ==================================================================================================
# Total params: 416,222,913
# Trainable params: 416,216,001
# Non-trainable params: 6,912
# __________________________________________________________________________________________________
